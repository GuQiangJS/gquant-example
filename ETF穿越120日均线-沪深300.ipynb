# %% [markdown]
# # ETF穿越120日均线
#
# * **买入：**收盘价上穿120日均线
# * **卖出：**收盘价下穿120日均线
#
# > 交易价格以每日均价为计算标准；
#
# ---
#
# 非常简单的策略。但是也只是略高于基准而已。（个人理解好处是可以避免买在山顶上而已，最大回撤降低50%以上）
#
# > 值得注意的是：交易次数较低。
#
# |        |   基准收益 |   策略收益 |   基准年化收益 |   策略年化收益 |   基准最大回撤 |   策略最大回撤 |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   策略浮动盈亏(未结束交易当前价值+剩余现金/初始资金) |
# |-------:|-----------:|-----------:|---------------:|---------------:|---------------:|---------------:|------------------------------------------:|-----------------------------------------------------:|
# | 510300 |   0.583337 |   0.724246 |      0.0787442 |      0.0977654 |      -0.461035 |      -0.173222 |                                   1.60564 |                                              1.82072 |
# | 510310 |   0.794892 |   1.13858  |      0.120365  |      0.172407  |      -0.456236 |      -0.124193 |                                   1.78368 |                                              2.21731 |
#
# |        |   初始资金 |   剩余现金 |   交易次数 |   未结束交易次数 |   未结束交易购买金额 |   未结束交易当前价值 |   盈利次数 |   亏损次数 |   盈利次数占比 |   盈利(含交易费)次数 |   亏损(含交易费)次数 |   盈利(含交易费)次数占比 |   盈利交易平均获利 |   亏损交易平均亏损 |   盈利(含交易费)交易平均获利 |   亏损(含交易费)交易平均亏损 |   盈亏总额 |   手续费总额 |   手续费均值 |   最大盈利% |   最大亏损% |   最大(含交易费)盈利% |   最大(含交易费)亏损% |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   结算价值(未结束交易当前价值+剩余现金) |   浮动盈亏(结算价值/初始资金) |
# |-------:|-----------:|-----------:|-----------:|-----------------:|---------------------:|---------------------:|-----------:|-----------:|---------------:|---------------------:|---------------------:|-------------------------:|-------------------:|-------------------:|-----------------------------:|-----------------------------:|-----------:|-------------:|-------------:|------------:|------------:|----------------------:|----------------------:|------------------------------------------:|----------------------------------------:|------------------------------:|
# | 510300 |      10000 |   184.777  |         29 |                1 |              17668.2 |              18022.4 |         14 |         13 |       0.482759 |                   14 |                   14 |                 0.482759 |            900.443 |           -347.765 |                      900.443 |                     -322.925 |    8085.25 |      232.273 |      4.07533 |    0.868096 |  -0.0815193 |              0.867235 |            -0.0820948 |                                   1.60564 |                                 18207.2 |                       1.82072 |
# | 510310 |      10000 |    42.3044 |         19 |                1 |              20758.3 |              22130.8 |         10 |          8 |       0.526316 |                   10 |                    8 |                 0.526316 |           1535.56  |           -546.981 |                     1535.56  |                     -546.981 |   10979.8  |      179.171 |      4.84384 |    0.918903 |  -0.081068  |              0.918028 |            -0.0816437 |                                   1.78368 |                                 22173.1 |                       2.21731 |
#
# ---
#
# **逐年统计：**
#
# **510310:**
#
# |                       |   基准浮动盈亏(基准最后收盘/基准最先开盘)cumsum |   浮动盈亏(结算价值/初始资金)cumsum |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   浮动盈亏(结算价值/初始资金) |   盈利次数 |   亏损次数 |   盈利(含交易费)交易平均获利 |   亏损(含交易费)交易平均亏损 |   未结束交易购买金额 |   未结束交易当前价值 |   基准最大回撤 |   策略最大回撤 |
# | 2017-01-01~2017-12-31 |                                         4.65861 |                             4.73713 |                                  1.21237  |                      1.14392  |          3 |          3 |                      68.2417 |                     -118.333 |               9785.3 |              11412.8 |      -0.061619 |     -0.014     |
# | 2018-01-01~2018-12-31 |                                         5.40726 |                             5.73136 |                                  0.748654 |                      0.994227 |          2 |          1 |                       9.3    |                      -58.8   |                  0   |                  0   |      -0.306743 |     -0.006     |
# | 2019-01-01~2019-12-31 |                                         6.74146 |                             6.87205 |                                  1.3342   |                      1.14069  |          3 |          0 |                     404.008  |                      nan     |              10841.8 |              11059.2 |      -0.135115 |      0         |
# | 2020-01-01~2020-12-31 |                                         8.02472 |                             8.12561 |                                  1.28325  |                      1.25356  |          2 |          4 |                     143.75   |                     -172.512 |               9183.9 |              12160.1 |      -0.161821 |     -0.0694162 |

# %%
import gquant
import abupy
import QUANTAXIS as QA
import gquant.jupyter_helper
gquant.jupyter_helper.init()
import talib
import matplotlib.pyplot as plt
import pandas as pd
from abupy.ExtBu.empyrical import stats

# %% [markdown]
# # 原始数据

# %%
START='1990-01-01'
END='2019-12-31'
DEFAULT_MA=120
CODE='510310'

def get_data(code, start, end,ma=DEFAULT_MA):
    data=QA.QA_fetch_index_day_adv(code,start=start,end=end)
    if not data:
        return None
    data=data.data.reset_index(level=1, drop=True)
    data['MA']=QA.MA(data['close'],ma)
    data['prev_MA']=data['MA'].shift()#昨天
    data['prev_close']=data['close'].shift()#昨天
    data['prev_bef_MA']=data['MA'].shift(2)#前天
    data['prev_bef_close']=data['close'].shift(2)#前天
    data['date'] = data.index.get_level_values(0)
    data['date'] = pd.to_datetime(data['date'])
    data['avg_price']=(data['close']+data['open']+data['high']+data['low'])/4
    # 星期一为0，星期天为6
    data['weekday'] = data['date'].dt.weekday
    data['nextday']=data['weekday'].shift(-1)
    data['prevday']=data['weekday'].shift()
    return data

# %%
# 易方达沪深300发起式ETF
data_000300=get_data('000300',start=START,end=END)
# 易方达沪深300发起式ETF
data_510310=get_data('510310',start=START,end=END)
# 华泰柏瑞沪深300ETF
data_510300=get_data('510300',start=START,end=END)

# %%
data_close=pd.DataFrame({'000300':data_000300.close,'510310':data_510310.close,'510300':data_510300.close}).dropna()
(data_close/data_close.iloc[0]).plot()
plt.legend()

# %%
data_close.pct_change().describe()
# Out:
#           000300     510310     510300
# count  1650.0000  1650.0000  1650.0000
# mean      0.0004     0.0005     0.0004
# std       0.0148     0.0156     0.0158
# min      -0.0875    -0.0997    -0.1001
# 25%      -0.0056    -0.0053    -0.0060
# 50%       0.0004     0.0000     0.0003
# 75%       0.0070     0.0066     0.0068
# max       0.0671     0.1002     0.0999

# %%
data_close.iloc[-1]/data_close.iloc[0]
# Out:
# 000300    1.5677
# 510310    1.7890
# 510300    1.5687
# dtype: float64

# %%
data_510300[['close','MA']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from gquant.backtest import backtest

def simple_trade_func(data,**kwargs):
    #昨日收盘价大于昨日120日均线价格，并且前日收盘价小于前日120日均线价格时买入
    data.loc[(data['prev_close'].shift()>data['prev_MA'].shift())&(data['prev_bef_close'].shift()<data['prev_bef_MA'].shift()),'buy']=1
    #昨日收盘价小于昨日120日均线价格，并且前日收盘价大于前日120日均线价格时卖出
    data.loc[(data['prev_close'].shift()<data['prev_MA'].shift())&(data['prev_bef_close'].shift()>data['prev_bef_MA'].shift()),'sell']=1
    return data

def simple_buy_price_func(index, row, data):
    return row['avg_price']

def simple_sell_price_func(index, row, data):
    return row['avg_price']

# %% [markdown]
# ## 510300
#
# 稍稍跑赢基准

# %%
x = get_data('510300', START, END)
x=simple_trade_func(x)
m1 = backtest(x, benchmark_pd=x, buy_comm=0, sell_comm=0, buy_limit_comm=0, sell_limit_comm=0,
             buy_price_func=simple_buy_price_func, sell_price_func=simple_sell_price_func)
m1.stats()
# m.report().to_frame().T
# m.plot_cash()
# Out:
# 1852it [00:00, 4574.60it/s]
# 基准收益                           0.5833
# 策略收益                           0.7242
# 基准年化收益                         0.0787
# 策略年化收益                         0.0978
# 基准最大回撤                        -0.4610
# 策略最大回撤                        -0.1732
# 基准浮动盈亏(基准最后收盘/基准最先开盘)          1.6056
# 策略浮动盈亏(未结束交易当前价值+剩余现金/初始资金)    1.8207
# dtype: float64

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(m1.report())
# Out:
# 初始资金                     10000.0000
# 剩余现金                       184.7771
# 交易次数                        29.0000
# 未结束交易次数                      1.0000
# 未结束交易购买金额                17668.2000
# 未结束交易当前价值                18022.4000
# 盈利次数                        14.0000
# 亏损次数                        13.0000
# 盈利次数占比                       0.4828
# 盈利(含交易费)次数                  14.0000
# 亏损(含交易费)次数                  14.0000
# 盈利(含交易费)次数占比                 0.4828
# 盈利交易平均获利                   900.4429
# 亏损交易平均亏损                  -347.7654
# 盈利(含交易费)交易平均获利             900.4429
# 亏损(含交易费)交易平均亏损            -322.9250
# 盈亏总额                      8085.2500
# 手续费总额                      232.2729
# 手续费均值                        4.0753
# 最大盈利%                        0.8681
# 最大亏损%                       -0.0815
# 最大(含交易费)盈利%                  0.8672
# 最大(含交易费)亏损%                 -0.0821
# 基准浮动盈亏(基准最后收盘/基准最先开盘)        1.6056
# 结算价值(未结束交易当前价值+剩余现金)     18207.1771
# 浮动盈亏(结算价值/初始资金)              1.8207
# ...

# %%
m1.plot_cash()

# %% [markdown]
# ## 510310
#
# 打赢基准

# %%
x = get_data('510310', START, END)
x=simple_trade_func(x)
m2 = backtest(x, benchmark_pd=x, buy_comm=0, sell_comm=0, buy_limit_comm=0, sell_limit_comm=0,
             buy_price_func=simple_buy_price_func, sell_price_func=simple_sell_price_func)
m2.stats()
# m.report().to_frame().T
# m.plot_cash()
# Out:
# 1651it [00:00, 4889.43it/s]
# 基准收益                           0.7949
# 策略收益                           1.1386
# 基准年化收益                         0.1204
# 策略年化收益                         0.1724
# 基准最大回撤                        -0.4562
# 策略最大回撤                        -0.1242
# 基准浮动盈亏(基准最后收盘/基准最先开盘)          1.7837
# 策略浮动盈亏(未结束交易当前价值+剩余现金/初始资金)    2.2173
# dtype: float64

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(m2.report())
# Out:
# 初始资金                     10000.0000
# 剩余现金                        42.3044
# 交易次数                        19.0000
# 未结束交易次数                      1.0000
# 未结束交易购买金额                20758.3000
# 未结束交易当前价值                22130.8000
# 盈利次数                        10.0000
# 亏损次数                         8.0000
# 盈利次数占比                       0.5263
# 盈利(含交易费)次数                  10.0000
# 亏损(含交易费)次数                   8.0000
# 盈利(含交易费)次数占比                 0.5263
# 盈利交易平均获利                  1535.5625
# 亏损交易平均亏损                  -546.9812
# 盈利(含交易费)交易平均获利            1535.5625
# 亏损(含交易费)交易平均亏损            -546.9812
# 盈亏总额                     10979.7750
# 手续费总额                      179.1706
# 手续费均值                        4.8438
# 最大盈利%                        0.9189
# 最大亏损%                       -0.0811
# 最大(含交易费)盈利%                  0.9180
# 最大(含交易费)亏损%                 -0.0816
# 基准浮动盈亏(基准最后收盘/基准最先开盘)        1.7837
# 结算价值(未结束交易当前价值+剩余现金)     22173.1044
# 浮动盈亏(结算价值/初始资金)              2.2173
# ...

# %%
m2.plot_cash()

# %% [markdown]
# |        |   基准收益 |   策略收益 |   基准年化收益 |   策略年化收益 |   基准最大回撤 |   策略最大回撤 |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   策略浮动盈亏(未结束交易当前价值+剩余现金/初始资金) |
# |-------:|-----------:|-----------:|---------------:|---------------:|---------------:|---------------:|------------------------------------------:|-----------------------------------------------------:|
# | 510300 |   0.583337 |   0.724246 |      0.0787442 |      0.0977654 |      -0.461035 |      -0.173222 |                                   1.60564 |                                              1.82072 |
# | 510310 |   0.794892 |   1.13858  |      0.120365  |      0.172407  |      -0.456236 |      -0.124193 |                                   1.78368 |                                              2.21731 |

# %%
print(pd.DataFrame({'510300':m1.stats(),'510310':m2.stats()}).T.to_markdown())
# Out:
# |        |   基准收益 |   策略收益 |   基准年化收益 |   策略年化收益 |   基准最大回撤 |   策略最大回撤 |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   策略浮动盈亏(未结束交易当前价值+剩余现金/初始资金) |
# |-------:|-----------:|-----------:|---------------:|---------------:|---------------:|---------------:|------------------------------------------:|-----------------------------------------------------:|
# | 510300 |   0.583337 |   0.724246 |      0.0787442 |      0.0977654 |      -0.461035 |      -0.173222 |                                   1.60564 |                                              1.82072 |
# | 510310 |   0.794892 |   1.13858  |      0.120365  |      0.172407  |      -0.456236 |      -0.124193 |                                   1.78368 |                                              2.21731 |

# %% [markdown]
# |        |   初始资金 |   剩余现金 |   交易次数 |   未结束交易次数 |   未结束交易购买金额 |   未结束交易当前价值 |   盈利次数 |   亏损次数 |   盈利次数占比 |   盈利(含交易费)次数 |   亏损(含交易费)次数 |   盈利(含交易费)次数占比 |   盈利交易平均获利 |   亏损交易平均亏损 |   盈利(含交易费)交易平均获利 |   亏损(含交易费)交易平均亏损 |   盈亏总额 |   手续费总额 |   手续费均值 |   最大盈利% |   最大亏损% |   最大(含交易费)盈利% |   最大(含交易费)亏损% |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   结算价值(未结束交易当前价值+剩余现金) |   浮动盈亏(结算价值/初始资金) |
# |-------:|-----------:|-----------:|-----------:|-----------------:|---------------------:|---------------------:|-----------:|-----------:|---------------:|---------------------:|---------------------:|-------------------------:|-------------------:|-------------------:|-----------------------------:|-----------------------------:|-----------:|-------------:|-------------:|------------:|------------:|----------------------:|----------------------:|------------------------------------------:|----------------------------------------:|------------------------------:|
# | 510300 |      10000 |   184.777  |         29 |                1 |              17668.2 |              18022.4 |         14 |         13 |       0.482759 |                   14 |                   14 |                 0.482759 |            900.443 |           -347.765 |                      900.443 |                     -322.925 |    8085.25 |      232.273 |      4.07533 |    0.868096 |  -0.0815193 |              0.867235 |            -0.0820948 |                                   1.60564 |                                 18207.2 |                       1.82072 |
# | 510310 |      10000 |    42.3044 |         19 |                1 |              20758.3 |              22130.8 |         10 |          8 |       0.526316 |                   10 |                    8 |                 0.526316 |           1535.56  |           -546.981 |                     1535.56  |                     -546.981 |   10979.8  |      179.171 |      4.84384 |    0.918903 |  -0.081068  |              0.918028 |            -0.0816437 |                                   1.78368 |                                 22173.1 |                       2.21731 |

# %%
print(pd.DataFrame({'510300':m1.report(),'510310':m2.report()}).T.to_markdown())
# Out:
# |        |   初始资金 |   剩余现金 |   交易次数 |   未结束交易次数 |   未结束交易购买金额 |   未结束交易当前价值 |   盈利次数 |   亏损次数 |   盈利次数占比 |   盈利(含交易费)次数 |   亏损(含交易费)次数 |   盈利(含交易费)次数占比 |   盈利交易平均获利 |   亏损交易平均亏损 |   盈利(含交易费)交易平均获利 |   亏损(含交易费)交易平均亏损 |   盈亏总额 |   手续费总额 |   手续费均值 |   最大盈利% |   最大亏损% |   最大(含交易费)盈利% |   最大(含交易费)亏损% |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   结算价值(未结束交易当前价值+剩余现金) |   浮动盈亏(结算价值/初始资金) |
# |-------:|-----------:|-----------:|-----------:|-----------------:|---------------------:|---------------------:|-----------:|-----------:|---------------:|---------------------:|---------------------:|-------------------------:|-------------------:|-------------------:|-----------------------------:|-----------------------------:|-----------:|-------------:|-------------:|------------:|------------:|----------------------:|----------------------:|------------------------------------------:|----------------------------------------:|------------------------------:|
# ...

# %% [markdown]
# ## 逐年统计
#
# 从`2014-01-01`至`2020-12-31`期间，每年从`01-01`开始投入`10000`元，以`510310`穿越120日均线为简单条件进行测试。
#
# 最后统计 `持仓数量\*最后一个交易日的收盘价+剩余现金` 作为**策略浮动盈亏**，与`基准数据最后一个交易日收盘价/基准数据第一个交易日开盘价`**基准浮动盈亏**进行对比。最终结果累加值稍高于基准。
#
# **但是交易频率过低。** 很难对收益率、最大回撤等指标进行比较。
#
# **510310:**
#
# |                       |   基准浮动盈亏(基准最后收盘/基准最先开盘)cumsum |   浮动盈亏(结算价值/初始资金)cumsum |   基准浮动盈亏(基准最后收盘/基准最先开盘) |   浮动盈亏(结算价值/初始资金) |   盈利次数 |   亏损次数 |   盈利(含交易费)交易平均获利 |   亏损(含交易费)交易平均亏损 |   未结束交易购买金额 |   未结束交易当前价值 |   基准最大回撤 |   策略最大回撤 |
# | 2018-01-01~2018-12-31 |                                         5.40726 |                             5.73136 |                                  0.748654 |                      0.994227 |          2 |          1 |                       9.3    |                      -58.8   |                  0   |                  0   |      -0.306743 |     -0.006     |
# | 2019-01-01~2019-12-31 |                                         6.74146 |                             6.87205 |                                  1.3342   |                      1.14069  |          3 |          0 |                     404.008  |                      nan     |              10841.8 |              11059.2 |      -0.135115 |      0         |
# | 2020-01-01~2020-12-31 |                                         8.02472 |                             8.12561 |                                  1.28325  |                      1.25356  |          2 |          4 |                     143.75   |                     -172.512 |               9183.9 |              12160.1 |      -0.161821 |     -0.0694162 |

# %%
d={}
x = get_data('510310', START, '2020-12-31')
for i in range(2014,2021):
    start='{}-01-01'.format(i)
    end='{}-12-31'.format(i)
    y=x.loc[start:end]
    y=simple_trade_func(y)
    m = backtest(y, benchmark_pd=y, buy_comm=0, sell_comm=0, buy_limit_comm=0, sell_limit_comm=0,
                     buy_price_func=simple_buy_price_func, sell_price_func=simple_sell_price_func)
    d['{}~{}'.format('{}-01-01'.format(i),end)]=m
    

every_year_stats = pd.DataFrame({k:v.stats() for k,v in d.items()}).T
every_year_reports = pd.DataFrame({k:v.report() for k,v in d.items()}).T
# Out:
# 245it [00:00, 5249.87it/s]
# 244it [00:00, 5046.38it/s]
# 244it [00:00, 5299.87it/s]
# 244it [00:00, 4195.90it/s]
# 243it [00:00, 4789.10it/s]
# 244it [00:00, 4820.49it/s]
# 243it [00:00, 4265.18it/s]

# %%
# print(every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)']].cumsum().join(every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)','盈利次数','亏损次数','盈利(含交易费)交易平均获利','亏损(含交易费)交易平均亏损','未结束交易购买金额','未结束交易当前价值']],lsuffix='cumsum').join(every_year_stats.sort_index()[['基准最大回撤','策略最大回撤']]).to_markdown())
every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)']].cumsum().join(every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)','盈利次数','亏损次数','盈利(含交易费)交易平均获利','亏损(含交易费)交易平均亏损','未结束交易购买金额','未结束交易当前价值']],lsuffix='cumsum').join(every_year_stats.sort_index()[['基准最大回撤','策略最大回撤']])
# Out:
#                        基准浮动盈亏(基准最后收盘/基准最先开盘)cumsum  浮动盈亏(结算价值/初始资金)cumsum  \
# 2014-01-01~2014-12-31                       1.5563                 1.6171
# 2015-01-01~2015-12-31                       2.6133                 2.5701
# 2016-01-01~2016-12-31                       3.5215                 3.6370
# 2017-01-01~2017-12-31                       4.7547                 4.8373
# 2018-01-01~2018-12-31                       5.5157                 5.7870
# 2019-01-01~2019-12-31                       6.9036                 6.9935
# 2020-01-01~2020-12-31                       8.1997                 8.2424
#
#                        基准浮动盈亏(基准最后收盘/基准最先开盘)  浮动盈亏(结算价值/初始资金)  盈利次数  亏损次数  \
# 2014-01-01~2014-12-31                 1.5563           1.6171   0.0   1.0
# 2015-01-01~2015-12-31                 1.0570           0.9529   1.0   1.0
# 2016-01-01~2016-12-31                 0.9082           1.0669   1.0   0.0
# 2017-01-01~2017-12-31                 1.2332           1.2003   3.0   1.0
# ...

# %%
d={}
x = get_data('510300', START, '2020-12-31')
for i in range(2014,2021):
    start='{}-01-01'.format(i)
    end='{}-12-31'.format(i)
    y=x.loc[start:end]
    y=simple_trade_func(y)
    m = backtest(y, benchmark_pd=y, buy_comm=0, sell_comm=0, buy_limit_comm=0, sell_limit_comm=0,
                     buy_price_func=simple_buy_price_func, sell_price_func=simple_sell_price_func)
    d['{}~{}'.format('{}-01-01'.format(i),end)]=m
    

every_year_stats = pd.DataFrame({k:v.stats() for k,v in d.items()}).T
every_year_reports = pd.DataFrame({k:v.report() for k,v in d.items()}).T

# print(every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)']].cumsum().join(every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)','盈利次数','亏损次数','盈利(含交易费)交易平均获利','亏损(含交易费)交易平均亏损','未结束交易购买金额','未结束交易当前价值']],lsuffix='cumsum').join(every_year_stats.sort_index()[['基准最大回撤','策略最大回撤']]).to_markdown())
every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)']].cumsum().join(every_year_reports.sort_index()[['基准浮动盈亏(基准最后收盘/基准最先开盘)','浮动盈亏(结算价值/初始资金)','盈利次数','亏损次数','盈利(含交易费)交易平均获利','亏损(含交易费)交易平均亏损','未结束交易购买金额','未结束交易当前价值']],lsuffix='cumsum').join(every_year_stats.sort_index()[['基准最大回撤','策略最大回撤']])
# Out:
# 245it [00:00, 5126.28it/s]
# 244it [00:00, 4522.30it/s]
# 244it [00:00, 4829.16it/s]
# 244it [00:00, 3664.51it/s]
# 243it [00:00, 4695.25it/s]
# 244it [00:00, 4473.65it/s]
# 243it [00:00, 3629.05it/s]
#                        基准浮动盈亏(基准最后收盘/基准最先开盘)cumsum  浮动盈亏(结算价值/初始资金)cumsum  \
# 2014-01-01~2014-12-31                       1.5087                 1.5913
# 2015-01-01~2015-12-31                       2.5569                 2.5235
# 2016-01-01~2016-12-31                       3.4462                 3.5932
# 2017-01-01~2017-12-31                       4.6586                 4.7371
# 2018-01-01~2018-12-31                       5.4073                 5.7314
# 2019-01-01~2019-12-31                       6.7415                 6.8720
# 2020-01-01~2020-12-31                       8.0247                 8.1256
#
#                        基准浮动盈亏(基准最后收盘/基准最先开盘)  浮动盈亏(结算价值/初始资金)  盈利次数  亏损次数  \
# 2014-01-01~2014-12-31                 1.5087           1.5913   0.0   1.0
# ...
